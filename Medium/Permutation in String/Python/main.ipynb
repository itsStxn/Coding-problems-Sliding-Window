# %% [markdown]
# # Longest Substring Without Repeating Characters

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.checkInclusion(s1 = "ab", s2 = "eidbaooo")
# Out:
# True

# %% [markdown]
# ## Test 2

# %%
task.checkInclusion(s1 = "ab", s2 = "eidboaoo")
# Out:
# False
