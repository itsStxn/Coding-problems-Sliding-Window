# %% [markdown]
# # Longest Repeating Character Replacement

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.characterReplacement(s = "ABAB", k = 2)
# Out:
# 4

# %% [markdown]
# ## Test 2

# %%
task.characterReplacement("AABABBA", k = 1)
# Out:
# 4
